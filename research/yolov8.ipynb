# %%
# %env CLEARML_WEB_HOST=https://app.clear.ml
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=WPGUDA86TNUTVJ4EIBYD
# %env CLEARML_API_SECRET_KEY=5OtEAVWKf1ABOAyduLfc0838F32IqzaVChdrxZ7gf81wItEJEm
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=WPGUDA86TNUTVJ4EIBYD
# env: CLEARML_API_SECRET_KEY=5OtEAVWKf1ABOAyduLfc0838F32IqzaVChdrxZ7gf81wItEJEm

# %%
# Pip install method (recommended)
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.110 🚀 Python-3.7.12 torch-1.11.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Setup complete ✅ (2 CPUs, 15.6 GB RAM, 4726.0/8062.4 GB disk)

# %%
from ultralytics import YOLO
 
# Load the model.
model = YOLO('runs/detect/yolov8s_result3/weights/last.pt')
 
# Training.
results = model.train(
   data='custom_data_only.yaml',
   imgsz=1240,
   epochs=3,
   batch=16,
   name='yolov8s_result4')
# Out:
# Ultralytics YOLOv8.0.110 🚀 Python-3.7.12 torch-1.11.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
# !zip -r yolov8s_result3.zip /kaggle/working/runs/detect/yolov8s_result3
# Out:
#   adding: kaggle/working/runs/detect/yolov8s_result3/ (stored 0%)
#   adding: kaggle/working/runs/detect/yolov8s_result3/confusion_matrix_normalized.png (deflated 9%)
#   adding: kaggle/working/runs/detect/yolov8s_result3/events.out.tfevents.1685302531.a17874b2105a.23.5 (deflated 71%)
#   adding: kaggle/working/runs/detect/yolov8s_result3/weights/ (stored 0%)
#   adding: kaggle/working/runs/detect/yolov8s_result3/weights/best.pt (deflated 8%)
#   adding: kaggle/working/runs/detect/yolov8s_result3/weights/last.pt (deflated 8%)
#   adding: kaggle/working/runs/detect/yolov8s_result3/labels.jpg (deflated 19%)
#   adding: kaggle/working/runs/detect/yolov8s_result3/val_batch0_labels.jpg (deflated 2%)
#   adding: kaggle/working/runs/detect/yolov8s_result3/R_curve.png (deflated 6%)
#   adding: kaggle/working/runs/detect/yolov8s_result3/val_batch0_pred.jpg (deflated 2%)
#   adding: kaggle/working/runs/detect/yolov8s_result3/train_batch1.jpg (deflated 4%)
# ...
